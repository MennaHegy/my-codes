# %%
! git clone https://github.com/mdciri/teeth-segmentation.git
# Out:
# Cloning into 'teeth-segmentation'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 54 (delta 19), reused 41 (delta 9), pack-reused 0
# Unpacking objects: 100% (54/54), 826.04 KiB | 6.35 MiB/s, done.

# %%
! pip install monai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.4 MB/s eta 0:00:00
# ...

# %%
cd teeth-segmentation
# Out:
# /content/teeth-segmentation

# %%
ls
# Out:
# augmentation.py  engine.py               gui.gif    loss.py    train.py
# data.json        evaluation.py           gui.py     metric.py
# data_split.py    evaluation_results.csv  loader.py  README.md

# %%
# !unzip "/content/teeth-segmentation/Segmentation.zip" -d "/content/teeth-segmentation"
# Out:
# Archive:  /content/teeth-segmentation/Segmentation.zip
#    creating: /content/teeth-segmentation/Segmentation/
#    creating: /content/teeth-segmentation/Segmentation/maxillomandibular/
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/1.jpg
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/100.jpg
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/1000.jpg
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/1001.jpg
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/1002.jpg
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/1004.jpg
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/1007.jpg
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/1008.jpg
#   inflating: /content/teeth-segmentation/Segmentation/maxillomandibular/1009.jpg
# ...

# %%
# !unzip "/content/teeth-segmentation/Radiographs.zip" -d "/content/teeth-segmentation"
# Out:
# Archive:  /content/teeth-segmentation/Radiographs.zip
#    creating: /content/teeth-segmentation/Radiographs/
#   inflating: /content/teeth-segmentation/Radiographs/1.JPG
#   inflating: /content/teeth-segmentation/Radiographs/100.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1000.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1001.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1002.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1004.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1007.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1008.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1009.JPG
#   inflating: /content/teeth-segmentation/Radiographs/101.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1010.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1011.JPG
#   inflating: /content/teeth-segmentation/Radiographs/1012.JPG
# ...

# %%
! python data_split.py
# Out:
# 100% 700/700 [00:00<00:00, 1147776.70it/s]
# 100% 200/200 [00:00<00:00, 1112547.48it/s]
# 100% 100/100 [00:00<00:00, 845625.81it/s]
# 100% 700/700 [00:14<00:00, 49.98it/s]

# %%
! python train.py -md "<model_directory>" -d "mps" -g 0 -bs 16 -lr 1.e-4 -ne 20
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# !python evaluation.py -md "<model_directory>" -d "mps" -g 0 -bs 1
# Out:
# python3: can't open file '/content/evaluation.py': [Errno 2] No such file or directory

# %%
# !python gui.py
